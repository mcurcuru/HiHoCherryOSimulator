# %%
import random
import math

spins = [-1, -2, -3, -4, 2, 2, 10]
turns = []
gameOn=True

for i in range(1):
    cherrybucket1 = 0
    turns1 = 0
    cherrybucket2 = 0
    turns2 = 0
    cherrybucket3 = 0
    turns3 = 0
    cherrybucket4 = 0
    turns4 = 0
    
    turns=turns1+turns2+turns3+turns4
    
    cherrytree=10

    while gameOn:

        spinIndex1 = random.randrange(0, 7)
        spinResult1 = spins[spinIndex1]

        print ("Player1, You spun:", str(spinResult1))

        cherrytree += spinResult1
        cherrybucket1-=spinResult1

        if cherrybucket1< 0:
            cherrybucket1 = 0
        elif cherrybucket1>=10:
            print('Player 1 Wins! Wait to see if another player will win on their last turn.')
            winner='Player 1'
            gameOn=False

        print ("Cherries in your bucket:", str(cherrybucket1))

        turns1 += 1
        
        spinIndex2 = random.randrange(0, 7)
        spinResult2 = spins[spinIndex2]

        print ("Player2, You spun:", str(spinResult2))

        cherrytree += spinResult2
        cherrybucket2-=spinResult2

        if cherrybucket2< 0:
            cherrybucket2 = 0
        elif cherrybucket2>=10:
            print('Player 2 Wins! Wait to see if another player will win on their last turn.')
            winner='Player 2'
            gameOn=False

        print ("Cherries in your bucket:", str(cherrybucket2))

        turns2 += 1
        
        spinIndex3 = random.randrange(0, 7)
        spinResult3 = spins[spinIndex3]

        print ("Player3, You spun:", str(spinResult3))

        cherrytree += spinResult3
        cherrybucket3-=spinResult3

        if cherrybucket3< 0:
            cherrybucket3 = 0
        elif cherrybucket3>=10:
            print('Player 3 Wins! Wait to see if another player will win on their last turn.')
            winner='Player 3'
            gameOn=False

        print ("Cherries in your bucket:", str(cherrybucket3))

        turns3 += 1
        
        spinIndex4 = random.randrange(0, 7)
        spinResult4 = spins[spinIndex4]

        print ("Player4, You spun:", str(spinResult4))

        cherrytree += spinResult4
        cherrybucket4-=spinResult4

        if cherrybucket4< 0:
            cherrybucket4 = 0
        elif cherrybucket4>=10:
            print('Player 4 Wins!')
            winner='Player 4'
            gameOn=False

        print ("Cherries in your bucket:", str(cherrybucket4))

        turns4 += 1
    
    print('The game is over on turn',turns4,'!')
    print('The winner(s) are:')
    if cherrybucket1>=10:
            print('Player 1')
    if cherrybucket2>=10:
            print('Player 2')
    if cherrybucket3>=10:
            print('Player 3')
    if cherrybucket4>=10:
            print('Player 4')
# Out:
# Player1, You spun: -3
# Cherries in your bucket: 3
# Player2, You spun: -4
# Cherries in your bucket: 4
# Player3, You spun: -1
# Cherries in your bucket: 1
# Player4, You spun: 2
# Cherries in your bucket: 0
# Player1, You spun: 2
# Cherries in your bucket: 1
# Player2, You spun: -1
# Cherries in your bucket: 5
# Player3, You spun: -2
# Cherries in your bucket: 3
# Player4, You spun: 10
# Cherries in your bucket: 0
# Player1, You spun: 2
# Cherries in your bucket: 0
# Player2, You spun: -4
# Cherries in your bucket: 9
# Player3, You spun: -4
# Cherries in your bucket: 7
# Player4, You spun: -2
# Cherries in your bucket: 2
# Player1, You spun: -2
# Cherries in your bucket: 2
# Player2, You spun: 2
# Cherries in your bucket: 7
# Player3, You spun: -4
# Player 3 Wins! Wait to see if another player will win on their last turn.
# Cherries in your bucket: 11
# Player4, You spun: -1
# Cherries in your bucket: 3
# The game is over on turn 4 !
# The winner(s) are:
# Player 3
